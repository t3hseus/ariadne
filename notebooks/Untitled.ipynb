# %%
# !pip list
# Out:
# Package                Version
# ---------------------- -------------------
# absl-py                0.9.0
# albumentations         0.4.3
# alembic                1.4.2
# appdirs                1.4.4
# ase                    3.20.1
# astor                  0.8.0
# astunparse             1.6.3
# async-generator        1.10
# attrs                  19.3.0
# audioread              2.1.9
# backcall               0.1.0
# beakerx                1.4.1
# biopython              1.78
# bleach                 3.1.4
# blinker                1.4
# boto                   2.49.0
# boto3                  1.10.44
# botocore               1.13.44
# bqplot                 0.12.0
# cached-property        1.5.2
# cachetools             3.1.1
# certifi                2020.12.5
# certipy                0.1.3
# cffi                   1.14.0
# chardet                3.0.4
# click                  7.1.2
# cloudpickle            1.4.1
# cryptography           2.9.2
# cupy-cuda100           6.5.0
# ...
